# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import CubicSpline
from pyplotz.pyplotz import plt


plt.rcParams['figure.dpi'] = 1000
plt.rcParams['figure.figsize'] = [7,5]

fig,ax=plt.subplots()
# plt.xticks([])
# plt.yticks([])
plt.xlim([-100, 100])
plt.ylim([-100, 100])
my_x_ticks = np.arange(-100, 100, 2)
my_y_ticks = np.arange(-100, 100, 2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)

ax.axes.xaxis.set_ticklabels([])
ax.axes.yaxis.set_ticklabels([])

plt.grid(True)

data = np.loadtxt('Data\\Cell Concentration\\k=0.txt') 

extent = (-100, 100, -100, 100 )

plt.imshow(data, extent=extent, cmap='Blues', vmin=-0, vmax=1)
plt.colorbar()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import CubicSpline
from pyplotz.pyplotz import plt


plt.rcParams['figure.dpi'] = 1000
plt.rcParams['figure.figsize'] = [7,5]

fig,ax=plt.subplots()
# plt.xticks([])
# plt.yticks([])
plt.xlim([-100, 100])
plt.ylim([-100, 100])
my_x_ticks = np.arange(-100, 100, 2)
my_y_ticks = np.arange(-100, 100, 2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)

ax.axes.xaxis.set_ticklabels([])
ax.axes.yaxis.set_ticklabels([])

plt.grid(True)

data = np.loadtxt('Data\\Cell Concentration\\k=100.txt') 

extent = (-100, 100, -100, 100 )

plt.imshow(data, extent=extent, cmap='Blues', vmin=-0, vmax=1)
plt.colorbar()
